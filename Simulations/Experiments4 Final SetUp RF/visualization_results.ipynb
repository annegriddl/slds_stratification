# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
file1 = "results-RF-14-12-2023.json"
file2 = "results-RF-15-12-2023-seed-1997.json"
file3= "results-RF-boxplot114-12-2023.json"

# %%
with open(file1) as f:
    data1 = json.load(f)

# %%
# Create an empty DataFrame
df = pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# create an empty list to store dataframes
dfs1 = []

# iterate through each entry in the json data
for entry in data1:
    # extract relevant information and results
    model_info = entry['model_info']
    results_unstratified = entry['unstratified_results']
    results_stratified = entry['stratified_results']

    # create a dataframe with the desired columns
    df_entry = pd.DataFrame({
        'model': [model_info['model']],
        'transformation': [model_info['transformation']],
        'n_train': [model_info['n_train']],
        'n_features': [model_info['n_features']],
        'n_groups': [model_info['n_groups']],
        'n_folds': [model_info['n_folds']],
        'n_iter': [model_info['n_iter']],
        'noise': [model_info['FD_noise']],
        'seed': [entry['seed']],
        'random_state': [entry['random_state']],
        'train_r2_unstratified': [results_unstratified['train r2']],
        'test_r2_unstratified': [results_unstratified['test r2']],
        'train_mse_unstratified': [results_unstratified['train mse']],
        'test_mse_unstratified': [results_unstratified['test mse']],
        'train_mae_unstratified': [results_unstratified['train mae']],
        'test_mae_unstratified': [results_unstratified['test mae']],
        'train_r2_stratified': [results_stratified['train r2']],
        'test_r2_stratified': [results_stratified['test r2']],
        'train_mse_stratified': [results_stratified['train mse']],
        'test_mse_stratified': [results_stratified['test mse']],
        'train_mae_stratified': [results_stratified['train mae']],
        'test_mae_stratified': [results_stratified['test mae']],
    })

    # append the dataframe to the list
    dfs1.append(df_entry)

# concatenate all dataframes in the list into a single dataframe
df1 = pd.concat(dfs1, ignore_index=True)

# display the resulting dataframe
print(df1)
# Out:
#                    model transformation  n_train  n_features  n_groups  \
# 0  RandomForestRegressor            log      500          10        10
# 1  RandomForestRegressor            log      500          10        10
# 2  RandomForestRegressor           sqrt      100          10        10
# 3  RandomForestRegressor           sqrt      100          10        10
# 4  RandomForestRegressor           sqrt      100          10        10
# 5  RandomForestRegressor           sqrt      100          10        10
# 6  RandomForestRegressor           sqrt      100          10        10
# 7  RandomForestRegressor           sqrt      100          10        10
#
#    n_folds  n_iter  noise  seed  random_state  ...  train_mse_unstratified  \
# 0        5      20      0    42          1825  ...                  0.0200
# 1        5      20      0    42           410  ...                  0.0086
# 2        5      50      0   100          2387  ...                  0.0287
# 3        5      50      0   100          7529  ...                  0.0176
# 4        5      50      0   100          2387  ...                  0.0287
# 5        5      50      0   100          7529  ...                  0.0176
# 6        5      50      0   100          2387  ...                  0.0287
# 7        5      50      0   100          2387  ...                  0.0287
#
#    test_mse_unstratified  train_mae_unstratified  test_mae_unstratified  \
# 0                 0.0358                  0.0918                 0.1357
# 1                 0.0322                  0.0579                 0.1312
# 2                 0.1508                  0.1313                 0.2977
# 3                 0.1330                  0.1041                 0.2898
# 4                 0.1508                  0.1313                 0.2977
# 5                 0.1330                  0.1041                 0.2898
# 6                 0.1508                  0.1313                 0.2977
# 7                 0.1508                  0.1313                 0.2977
#
#    train_r2_stratified  test_r2_stratified  train_mse_stratified  \
# 0               0.8783              0.7908                0.0175
# 1               0.9499              0.7986                0.0086
# 2               0.9358              0.6710                0.0287
# 3               0.9612              0.7099                0.0176
# 4               0.9358              0.6710                0.0287
# 5               0.9612              0.7099                0.0176
# 6               0.9358              0.6710                0.0287
# 7               0.9358              0.6710                0.0287
#
#    test_mse_stratified  train_mae_stratified  test_mae_stratified
# 0               0.0335                0.0862               0.1328
# 1               0.0322                0.0579               0.1312
# 2               0.1508                0.1313               0.2977
# 3               0.1330                0.1041               0.2898
# 4               0.1508                0.1313               0.2977
# 5               0.1330                0.1041               0.2898
# 6               0.1508                0.1313               0.2977
# 7               0.1508                0.1313               0.2977
#
# [8 rows x 22 columns]

# %%
with open(file2) as f:
    data2 = json.load(f)

# %%
# create an empty list to store dataframes
dfs2 = []

# iterate through each entry in the json data
for entry in data2:
    # extract relevant information and results
    model_info = entry['model_info']
    results_unstratified = entry['unstratified_results']
    results_stratified = entry['stratified_results']

    # create a dataframe with the desired columns
    df_entry = pd.DataFrame({
        'model': [model_info['model']],
        'transformation': [model_info['transformation']],
        'n_train': [model_info['n_train']],
        'n_features': [model_info['n_features']],
        'n_groups': [model_info['n_groups']],
        'n_folds': [model_info['n_folds']],
        'n_iter': [model_info['n_iter']],
        'noise': [model_info['FD_noise']],
        'seed': [entry['seed']],
        'random_state': [entry['random_state']],
        'train_r2_unstratified': [results_unstratified['train r2']],
        'test_r2_unstratified': [results_unstratified['test r2']],
        'train_mse_unstratified': [results_unstratified['train mse']],
        'test_mse_unstratified': [results_unstratified['test mse']],
        'train_mae_unstratified': [results_unstratified['train mae']],
        'test_mae_unstratified': [results_unstratified['test mae']],
        'train_r2_stratified': [results_stratified['train r2']],
        'test_r2_stratified': [results_stratified['test r2']],
        'train_mse_stratified': [results_stratified['train mse']],
        'test_mse_stratified': [results_stratified['test mse']],
        'train_mae_stratified': [results_stratified['train mae']],
        'test_mae_stratified': [results_stratified['test mae']],
    })

    # append the dataframe to the list
    dfs2.append(df_entry)

# concatenate all dataframes in the list into a single dataframe
df2 = pd.concat(dfs2, ignore_index=True)

# display the resulting dataframe
df2.head()
# Out:
#                    model transformation  n_train  n_features  n_groups  \
# 0  RandomForestRegressor            log      500          10        20
# 1  RandomForestRegressor            log      500          10        20
# 2  RandomForestRegressor            log      500          10        20
# 3  RandomForestRegressor            log      500          10        20
# 4  RandomForestRegressor            log      500          10        20
#
#    n_folds  n_iter  noise  seed  random_state  ...  train_mse_unstratified  \
# 0        5     100      0  1997          3858  ...                  0.0072
# 1        5     100      0  1997          1092  ...                  0.0048
# 2        5     100      0  1997          3624  ...                  0.0051
# 3        5     100      0  1997          2072  ...                  0.0106
# 4        5     100      0  1997          3629  ...                  0.0049
#
#    test_mse_unstratified  train_mae_unstratified  test_mae_unstratified  \
# 0                 0.0318                  0.0598                 0.1246
# 1                 0.0260                  0.0490                 0.1155
# 2                 0.0284                  0.0513                 0.1227
# 3                 0.0318                  0.0738                 0.1255
# 4                 0.0318                  0.0506                 0.1215
#
#    train_r2_stratified  test_r2_stratified  train_mse_stratified  \
# 0               0.9422              0.8073                0.0086
# 1               0.9727              0.8372                0.0048
# 2               0.9666              0.8227                0.0051
# 3               0.9279              0.8009                0.0106
# 4               0.9628              0.8008                0.0049
#
#    test_mse_stratified  train_mae_stratified  test_mae_stratified
# 0               0.0308                0.0650               0.1246
# 1               0.0260                0.0490               0.1155
# 2               0.0284                0.0513               0.1227
# 3               0.0318                0.0738               0.1255
# 4               0.0318                0.0506               0.1215
#
# [5 rows x 22 columns]

# %%
with open(file3) as f:
    data3 = json.load(f)

# %%
# create an empty list to store dataframes
dfs3 = []

# iterate through each entry in the json data
for entry in data3:
    # extract relevant information and results
    model_info = entry['model_info']
    results_unstratified = entry['unstratified_results']
    results_stratified = entry['stratified_results']

    # create a dataframe with the desired columns
    df_entry = pd.DataFrame({
        'model': [model_info['model']],
        'transformation': [model_info['transformation']],
        'n_train': [model_info['n_train']],
        'n_features': [model_info['n_features']],
        'n_groups': [model_info['n_groups']],
        'n_folds': [model_info['n_folds']],
        'n_iter': [model_info['n_iter']],
        'noise': [model_info['FD_noise']],
        'seed': [entry['seed']],
        'random_state': [entry['random_state']],
        'train_r2_unstratified': [results_unstratified['train r2']],
        'test_r2_unstratified': [results_unstratified['test r2']],
        'train_mse_unstratified': [results_unstratified['train mse']],
        'test_mse_unstratified': [results_unstratified['test mse']],
        'train_mae_unstratified': [results_unstratified['train mae']],
        'test_mae_unstratified': [results_unstratified['test mae']],
        'train_r2_stratified': [results_stratified['train r2']],
        'test_r2_stratified': [results_stratified['test r2']],
        'train_mse_stratified': [results_stratified['train mse']],
        'test_mse_stratified': [results_stratified['test mse']],
        'train_mae_stratified': [results_stratified['train mae']],
        'test_mae_stratified': [results_stratified['test mae']],
    })

    # append the dataframe to the list
    dfs3.append(df_entry)

# concatenate all dataframes in the list into a single dataframe
df3 = pd.concat(dfs3, ignore_index=True)

# display the resulting dataframe
df3.head()
# Out:
#                    model transformation  n_train  n_features  n_groups  \
# 0  RandomForestRegressor           sqrt     1000          10        10
# 1  RandomForestRegressor           sqrt     1000          10        10
# 2  RandomForestRegressor           sqrt     1000          10        10
# 3  RandomForestRegressor           sqrt     1000          10        10
# 4  RandomForestRegressor           sqrt     1000          10        10
#
#    n_folds  n_iter  noise  seed  random_state  ...  train_mse_unstratified  \
# 0        5     200      0   100          2387  ...                  0.0101
# 1        5     200      0   100          7529  ...                  0.0084
# 2        5     200      0   100          7454  ...                  0.0074
# 3        5     200      0   100          2864  ...                  0.0077
# 4        5     200      0   100          6440  ...                  0.0109
#
#    test_mse_unstratified  train_mae_unstratified  test_mae_unstratified  \
# 0                 0.0634                  0.0760                 0.1962
# 1                 0.0541                  0.0699                 0.1816
# 2                 0.0537                  0.0660                 0.1811
# 3                 0.0524                  0.0690                 0.1775
# 4                 0.0561                  0.0799                 0.1847
#
#    train_r2_stratified  test_r2_stratified  train_mse_stratified  \
# 0               0.9767              0.8617                0.0101
# 1               0.9822              0.8819                0.0084
# 2               0.9842              0.8829                0.0074
# 3               0.9840              0.8857                0.0077
# 4               0.9762              0.8776                0.0109
#
#    test_mse_stratified  train_mae_stratified  test_mae_stratified
# 0               0.0634                0.0760               0.1962
# 1               0.0541                0.0699               0.1816
# 2               0.0537                0.0656               0.1809
# 3               0.0524                0.0690               0.1775
# 4               0.0561                0.0799               0.1847
#
# [5 rows x 22 columns]

# %%
data = pd.concat([df2, df3], ignore_index=True)

# %%
# Out:
#                     model transformation  n_train  n_features  n_groups  \
# 0   RandomForestRegressor            log      500          10        20
# 1   RandomForestRegressor            log      500          10        20
# 2   RandomForestRegressor            log      500          10        20
# 3   RandomForestRegressor            log      500          10        20
# 4   RandomForestRegressor            log      500          10        20
# 5   RandomForestRegressor            log      500          10        20
# 6   RandomForestRegressor            log      500          10        20
# 7   RandomForestRegressor            log      500          10        20
# 8   RandomForestRegressor            log      500          10        20
# 9   RandomForestRegressor            log      500          10        20
# 10  RandomForestRegressor            log      500          10        20
# 11  RandomForestRegressor            log      500          10        20
# 12  RandomForestRegressor            log      500          10        20
# 13  RandomForestRegressor            log      500          10        20
# 14  RandomForestRegressor            log      500          10        20
# 15  RandomForestRegressor            log      500          10        20
# 16  RandomForestRegressor            log      500          10        20
# 17  RandomForestRegressor            log      500          10        20
# 18  RandomForestRegressor            log      500          10        20
# 19  RandomForestRegressor            log      500          10        20
# 20  RandomForestRegressor            log      500          10        20
# 21  RandomForestRegressor            log      500          10        20
# 22  RandomForestRegressor            log      500          10        20
# 23  RandomForestRegressor           sqrt     1000          10        10
# 24  RandomForestRegressor           sqrt     1000          10        10
# 25  RandomForestRegressor           sqrt     1000          10        10
# 26  RandomForestRegressor           sqrt     1000          10        10
# 27  RandomForestRegressor           sqrt     1000          10        10
# 28  RandomForestRegressor           sqrt     1000          10        10
# 29  RandomForestRegressor           sqrt     1000          10        10
# 30  RandomForestRegressor           sqrt     1000          10        10
#
#     n_folds  n_iter  noise  seed  random_state  ...  train_mse_unstratified  \
# 0         5     100      0  1997          3858  ...                  0.0072
# 1         5     100      0  1997          1092  ...                  0.0048
# 2         5     100      0  1997          3624  ...                  0.0051
# 3         5     100      0  1997          2072  ...                  0.0106
# 4         5     100      0  1997          3629  ...                  0.0049
# 5         5     100      0  1997          6399  ...                  0.0057
# 6         5     100      0  1997          5406  ...                  0.0072
# 7         5     100      0  1997          7204  ...                  0.0054
# 8         5     100      0  1997          4032  ...                  0.0037
# 9         5     100      0  1997          3760  ...                  0.0032
# 10        5     100      0  1997           904  ...                  0.0053
# 11        5     100      0  1997          6627  ...                  0.0035
# 12        5     100      0  1997          4681  ...                  0.0069
# 13        5     100      0  1997          2807  ...                  0.0058
# 14        5     100      0  1997           522  ...                  0.0042
# 15        5     100      0  1997          6551  ...                  0.0066
# 16        5     100      0  1997          9667  ...                  0.0049
# 17        5     100      0  1997          1669  ...                  0.0039
# 18        5     100      0  1997          3810  ...                  0.0040
# 19        5     100      0  1997          5358  ...                  0.0073
# 20        5     100      0  1997          5441  ...                  0.0061
# 21        5     100      0  1997          4256  ...                  0.0082
# 22        5     100      0  1997           939  ...                  0.0042
# 23        5     200      0   100          2387  ...                  0.0101
# 24        5     200      0   100          7529  ...                  0.0084
# 25        5     200      0   100          7454  ...                  0.0074
# 26        5     200      0   100          2864  ...                  0.0077
# 27        5     200      0   100          6440  ...                  0.0109
# 28        5     200      0   100          5731  ...                  0.0084
# 29        5     200      0   100          7103  ...                  0.0120
# 30        5     200      0   100          8305  ...                  0.0116
#
#     test_mse_unstratified  train_mae_unstratified  test_mae_unstratified  \
# 0                  0.0318                  0.0598                 0.1246
# 1                  0.0260                  0.0490                 0.1155
# 2                  0.0284                  0.0513                 0.1227
# 3                  0.0318                  0.0738                 0.1255
# 4                  0.0318                  0.0506                 0.1215
# 5                  0.0280                  0.0527                 0.1235
# 6                  0.0319                  0.0582                 0.1284
# 7                  0.0307                  0.0498                 0.1252
# 8                  0.0256                  0.0451                 0.1159
# 9                  0.0299                  0.0419                 0.1239
# 10                 0.0266                  0.0523                 0.1186
# 11                 0.0316                  0.0439                 0.1245
# 12                 0.0269                  0.0542                 0.1202
# 13                 0.0270                  0.0491                 0.1174
# 14                 0.0294                  0.0460                 0.1233
# 15                 0.0270                  0.0546                 0.1199
# 16                 0.0301                  0.0464                 0.1223
# 17                 0.0304                  0.0455                 0.1232
# 18                 0.0285                  0.0457                 0.1221
# 19                 0.0299                  0.0612                 0.1234
# 20                 0.0277                  0.0529                 0.1196
# 21                 0.0292                  0.0668                 0.1215
# 22                 0.0274                  0.0478                 0.1189
# 23                 0.0634                  0.0760                 0.1962
# 24                 0.0541                  0.0699                 0.1816
# 25                 0.0537                  0.0660                 0.1811
# 26                 0.0524                  0.0690                 0.1775
# 27                 0.0561                  0.0799                 0.1847
# 28                 0.0564                  0.0713                 0.1865
# 29                 0.0527                  0.0835                 0.1794
# 30                 0.0542                  0.0833                 0.1822
#
#     train_r2_stratified  test_r2_stratified  train_mse_stratified  \
# 0                0.9422              0.8073                0.0086
# 1                0.9727              0.8372                0.0048
# 2                0.9666              0.8227                0.0051
# 3                0.9279              0.8009                0.0106
# 4                0.9628              0.8008                0.0049
# 5                0.9659              0.8246                0.0057
# 6                0.9512              0.8004                0.0072
# 7                0.9604              0.8121                0.0060
# 8                0.9800              0.8396                0.0037
# 9                0.9791              0.8127                0.0032
# 10               0.9646              0.8338                0.0053
# 11               0.9750              0.8026                0.0035
# 12               0.9621              0.8315                0.0069
# 13               0.9710              0.8355                0.0049
# 14               0.9744              0.8161                0.0042
# 15               0.9620              0.8281                0.0063
# 16               0.9507              0.8029                0.0075
# 17               0.9729              0.8098                0.0039
# 18               0.9721              0.8218                0.0040
# 19               0.9513              0.8132                0.0073
# 20               0.9652              0.8270                0.0061
# 21               0.9501              0.8171                0.0082
# 22               0.9731              0.8285                0.0042
# 23               0.9767              0.8617                0.0101
# 24               0.9822              0.8819                0.0084
# 25               0.9842              0.8829                0.0074
# 26               0.9840              0.8857                0.0077
# 27               0.9762              0.8776                0.0109
# 28               0.9823              0.8770                0.0084
# 29               0.9775              0.8840                0.0106
# 30               0.9748              0.8819                0.0116
#
#     test_mse_stratified  train_mae_stratified  test_mae_stratified
# 0                0.0308                0.0650               0.1246
# 1                0.0260                0.0490               0.1155
# 2                0.0284                0.0513               0.1227
# 3                0.0318                0.0738               0.1255
# 4                0.0318                0.0506               0.1215
# 5                0.0280                0.0527               0.1235
# 6                0.0319                0.0582               0.1284
# 7                0.0300                0.0502               0.1241
# 8                0.0256                0.0451               0.1159
# 9                0.0299                0.0419               0.1239
# 10               0.0266                0.0523               0.1186
# 11               0.0316                0.0439               0.1245
# 12               0.0269                0.0542               0.1202
# 13               0.0263                0.0458               0.1157
# 14               0.0294                0.0460               0.1233
# 15               0.0275                0.0539               0.1212
# 16               0.0315                0.0558               0.1256
# 17               0.0304                0.0455               0.1232
# 18               0.0285                0.0457               0.1221
# 19               0.0299                0.0612               0.1234
# 20               0.0277                0.0529               0.1196
# 21               0.0292                0.0668               0.1215
# 22               0.0274                0.0478               0.1189
# 23               0.0634                0.0760               0.1962
# 24               0.0541                0.0699               0.1816
# 25               0.0537                0.0656               0.1809
# 26               0.0524                0.0690               0.1775
# 27               0.0561                0.0799               0.1847
# 28               0.0564                0.0713               0.1865
# 29               0.0532                0.0790               0.1804
# 30               0.0542                0.0833               0.1822
#
# [31 rows x 22 columns]

# %%
metric='r2'
def create_boxplot(df, metric, title):

    order = [
        f'train_{metric}_unstratified', f'train_{metric}_stratified',
        f'test_{metric}_unstratified', f'test_{metric}_stratified'
    ]
    df_melted = pd.melt(df, value_vars=order, var_name='Metric', value_name='Value')
    plt.figure(figsize=(7, 8))
    ax = sns.boxplot(x='Metric', y='Value', #hue='Stratification', 
                     data=df_melted,
                     order=order,
                     showmeans=True,
                     meanline=True,
                     color= "grey",
                     meanprops={"marker":"+",
                                "markerfacecolor":"white", 
                                "markeredgecolor":"green",
                                "markersize":"10"},
                                width=.5,
                                linecolor="#137", linewidth=.75,
                                medianprops={"color": "#137", "linewidth": 1})
    ax.set_xlabel('')
    ax.set_ylabel(metric.upper())
    #plt.xticks(rotation=0, ha='center', labels=['Train Unstratified', 'Train Stratified', 'Test Unstratified', 'Test Stratified'])
    xtickNames = plt.setp(ax, xticklabels=['Train Unstratified', 'Train Stratified', 'Test Unstratified', 'Test Stratified'])
    plt.setp(xtickNames, rotation=0)

    plt.title(title)
    
    
    plt.show()

# %%
create_boxplot(df, metric, 'Comparison of Stratified and Unstratified R²')
# Out:
# C:\Users\anneg\AppData\Local\Temp\ipykernel_16552\3300873400.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   xtickNames = plt.setp(ax, xticklabels=['Train Unstratified', 'Train Stratified', 'Test Unstratified', 'Test Stratified'])

# %%
create_boxplot(df, 'mse', 'Comparison of Stratified and Unstratified MSE')
# Out:
# C:\Users\anneg\AppData\Local\Temp\ipykernel_16552\3300873400.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   xtickNames = plt.setp(ax, xticklabels=['Train Unstratified', 'Train Stratified', 'Test Unstratified', 'Test Stratified'])

# %%
create_boxplot(df, 'mae', 'Comparison of Stratified and Unstratified MAE')
# Out:
# C:\Users\anneg\AppData\Local\Temp\ipykernel_16552\3300873400.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   xtickNames = plt.setp(ax, xticklabels=['Train Unstratified', 'Train Stratified', 'Test Unstratified', 'Test Stratified'])
