# %% [markdown]
# # Check raw data from json files
# Here some general checks of the json files are done. Here we do NOT evalute by the unique parameter combinaitons.

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import os
from utils_evaluation import flatten_data

# remove waringns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data for evaluation

# %%
# set file path to json files (change model) -> get names of json files
json_path = "/Users/nadja/Documents/University/Master_Statistik/WS2023_24/SLDS/slds_stratification/Simulations/Final_Setup/results/xgb/"
json_files = os.listdir(json_path)


# load data from json file
data = []
for file in json_files:
    with open(json_path + file) as f:
        data_new = json.load(f)
        data = data + data_new

# flatten dictionary and convert to dataframe
data_all_flatten, keys_dic = flatten_data(data)
data = pd.DataFrame(data_all_flatten)
print('Shape of data', data.shape)
print('Colum names of data', data.columns)
print('Number of Colums', data.columns.shape)
print('Keys of dictionary (', len(keys_dic), ')', keys_dic)


# check for duplicates ind data
print('Duplicates: ', data.astype(str).duplicated().sum())


data.head()
# Out:
# Shape of data (4800, 87)
# Colum names of data Index(['model_info_model', 'model_info_n_train', 'model_info_n_test',
#        'model_info_n_features', 'model_info_noise',
#        'model_info_transformation', 'model_info_group_size',
#        'model_info_n_folds', 'model_info_n_iter', 'model_info_n_repetitions',
#        'model_info_scoring', 'model_info_n_jobs', 'model_info_json_file',
#        'repetition', 'random_state', 'hyperparameters_same',
#        'unstratified_results_train r2', 'unstratified_results_test r2',
#        'unstratified_results_train mse', 'unstratified_results_test mse',
#        'unstratified_results_train mae', 'unstratified_results_test mae',
#        'stratified_results_train r2', 'stratified_results_test r2',
#        'stratified_results_train mse', 'stratified_results_test mse',
#        'stratified_results_train mae', 'stratified_results_test mae',
#        'cv_unstratified_iterations_mean_fit_time',
#        'cv_unstratified_iterations_std_fit_time',
#        'cv_unstratified_iterations_mean_score_time',
#        'cv_unstratified_iterations_std_score_time',
#        'cv_unstratified_iterations_param_subsample',
#        'cv_unstratified_iterations_param_min_child_weight',
#        'cv_unstratified_iterations_param_max_depth',
#        'cv_unstratified_iterations_param_learning_rate',
#        'cv_unstratified_iterations_param_gamma',
#        'cv_unstratified_iterations_param_colsample_bytree',
#        'cv_unstratified_iterations_params',
#        'cv_unstratified_iterations_split0_test_score',
#        'cv_unstratified_iterations_split1_test_score',
#        'cv_unstratified_iterations_split2_test_score',
#        'cv_unstratified_iterations_split3_test_score',
#        'cv_unstratified_iterations_split4_test_score',
#        'cv_unstratified_iterations_mean_test_score',
#        'cv_unstratified_iterations_std_test_score',
#        'cv_unstratified_iterations_rank_test_score',
#        'cv_stratified_iterations_mean_fit_time',
#        'cv_stratified_iterations_std_fit_time',
#        'cv_stratified_iterations_mean_score_time',
#        'cv_stratified_iterations_std_score_time',
#        'cv_stratified_iterations_param_subsample',
#        'cv_stratified_iterations_param_min_child_weight',
#        'cv_stratified_iterations_param_max_depth',
#        'cv_stratified_iterations_param_learning_rate',
#        'cv_stratified_iterations_param_gamma',
#        'cv_stratified_iterations_param_colsample_bytree',
#        'cv_stratified_iterations_params',
#        'cv_stratified_iterations_split0_test_score',
#        'cv_stratified_iterations_split1_test_score',
#        'cv_stratified_iterations_split2_test_score',
#        'cv_stratified_iterations_split3_test_score',
#        'cv_stratified_iterations_split4_test_score',
#        'cv_stratified_iterations_mean_test_score',
#        'cv_stratified_iterations_std_test_score',
#        'cv_stratified_iterations_rank_test_score',
#        'cv_iteration_refit_test_r2', 'cv_iteration_refit_test_mse',
#        'cv_iteration_refit_test_mae',
#        'cv_folds_descriptives_unstratified_ks_statistic',
#        'cv_folds_descriptives_unstratified_p_value',
#        'cv_folds_descriptives_unstratified_intersection_area',
#        'cv_folds_descriptives_stratified_ks_statistic',
#        'cv_folds_descriptives_stratified_p_value',
#        'cv_folds_descriptives_stratified_intersection_area',
#        'unstratified_best_params_subsample',
#        'unstratified_best_params_min_child_weight',
#        'unstratified_best_params_max_depth',
#        'unstratified_best_params_learning_rate',
#        'unstratified_best_params_gamma',
#        'unstratified_best_params_colsample_bytree',
#        'stratified_best_params_subsample',
#        'stratified_best_params_min_child_weight',
#        'stratified_best_params_max_depth',
#        'stratified_best_params_learning_rate', 'stratified_best_params_gamma',
#        'stratified_best_params_colsample_bytree'],
#       dtype='object')
# Number of Colums (87,)
# Keys of dictionary ( 10 ) ['cv_unstratified_iterations', 'cv_iteration_refit_test', 'cv_stratified_iterations', 'cv_folds_descriptives_unstratified', 'unstratified_results', 'unstratified_best_params', 'stratified_best_params', 'cv_folds_descriptives_stratified', 'model_info', 'stratified_results']
# Duplicates:  0
#   model_info_model  model_info_n_train  model_info_n_test  \
# 0              xgb                 200             100000
# 1              xgb                 200             100000
# 2              xgb                 200             100000
# 3              xgb                 200             100000
# 4              xgb                 200             100000
#
#    model_info_n_features  model_info_noise model_info_transformation  \
# 0                      8                 0                  identity
# 1                      8                 0                  identity
# 2                      8                 0                  identity
# 3                      8                 0                  identity
# 4                      8                 0                  identity
#
#    model_info_group_size  model_info_n_folds  model_info_n_iter  \
# 0                      5                   5                200
# 1                      5                   5                200
# 2                      5                   5                200
# 3                      5                   5                200
# 4                      5                   5                200
#
#    model_info_n_repetitions  ... unstratified_best_params_max_depth  \
# 0                        20  ...                                  2
# 1                        20  ...                                  2
# 2                        20  ...                                  2
# 3                        20  ...                                  2
# 4                        20  ...                                 17
#
#    unstratified_best_params_learning_rate unstratified_best_params_gamma  \
# 0                                0.222667                       1.000000
# 1                                0.267000                       3.786479
# 2                                0.267000                       1.945888
# 3                                0.222667                       1.945888
# 4                                0.178333                       1.394951
#
#    unstratified_best_params_colsample_bytree  \
# 0                                   0.687279
# 1                                   0.982669
# 2                                   0.548831
# 3                                   0.982669
# 4                                   0.976185
#
#    stratified_best_params_subsample  stratified_best_params_min_child_weight  \
# 0                          0.847472                                        2
# 1                          0.729761                                        6
# 2                          0.997877                                        2
# 3                          0.997877                                        4
# 4                          0.697330                                        6
#
#    stratified_best_params_max_depth  stratified_best_params_learning_rate  \
# 0                                 2                              0.311333
# 1                                 2                              0.222667
# 2                                 2                              0.222667
# 3                                 2                              0.134000
# 4                                 3                              0.222667
#
#    stratified_best_params_gamma  stratified_best_params_colsample_bytree
# 0                      1.000000                                 0.982669
# 1                      3.786479                                 0.982669
# 2                      1.000000                                 0.585893
# 3                      1.000000                                 0.517950
# 4                      1.394951                                 0.548831
#
# [5 rows x 87 columns]

# %% [markdown]
# ## Descriptives
# #### Single variables, no dictionnaries/lists
# * repetition', 'random_state', 'hyperparameters_same'
# * 'running_time_unstratified', 'running_time_stratified', 'running_time_repetition', 'cv_unstratified_iterations_mean_fit_time'

# %%
#  'hyperparameters_same'
data['hyperparameters_same'].value_counts()
# Out:
# hyperparameters_same
# False    3711
# True     1089
# Name: count, dtype: int64

# %%
# check 'random_state' unique
print(len(data['random_state']))
print(len(data['random_state'].unique()))
# Out:
# 4800
# 4800

# %%
# check 'repetition' complete
data['repetition'].value_counts().unique()
# Out:
# array([168, 120,  72,  48])

# %% [markdown]
# ### Data dictionnaries in json file

# %%
# overview of keys
print('keys_dic:', len(keys_dic), keys_dic)
# Out:
# keys_dic: 10 ['cv_unstratified_iterations', 'cv_iteration_refit_test', 'cv_stratified_iterations', 'cv_folds_descriptives_unstratified', 'unstratified_results', 'unstratified_best_params', 'stratified_best_params', 'cv_folds_descriptives_stratified', 'model_info', 'stratified_results']

# %% [markdown]
# #### model_info

# %%
# Filter columns that contain 'model_info'
key = 'model_info'
colum = [col for col in data.columns if key in col] 
colum
# Out:
# ['model_info_model',
#  'model_info_n_train',
#  'model_info_n_test',
#  'model_info_n_features',
#  'model_info_noise',
#  'model_info_transformation',
#  'model_info_group_size',
#  'model_info_n_folds',
#  'model_info_n_iter',
#  'model_info_n_repetitions',
#  'model_info_scoring',
#  'model_info_n_jobs',
#  'model_info_json_file']

# %%
# give summary of every column
data_desciptives = data.loc[:, colum]
# in data_desciptives make all columns categorical
data_desciptives = data_desciptives.astype('category')
# show summary of every column
data_desciptives.describe(include='all')
# Out:
#        model_info_model  model_info_n_train  model_info_n_test  \
# count              4800                4800               4800
# unique                1                   2                  1
# top                 xgb                 200             100000
# freq               4800                2400               4800
#
#         model_info_n_features  model_info_noise model_info_transformation  \
# count                    4800              4800                      4800
# unique                      1                 2                         3
# top                         8                 0                  identity
# freq                     4800              2400                      1600
#
#         model_info_group_size  model_info_n_folds  model_info_n_iter  \
# count                    4800                4800               4800
# unique                      2                   1                  1
# top                         5                   5                200
# freq                     2400                4800               4800
#
#         model_info_n_repetitions      model_info_scoring  model_info_n_jobs  \
# count                       4800                    4800               4800
# unique                         4                       1                  2
# top                           50  neg_mean_squared_error                  1
# freq                        2400                    4800               4080
#
#                                      model_info_json_file
# count                                                4800
# unique                                                  7
# top     /home/annegriddl/slds_stratification/Simulatio...
# freq                                                 1200

# %%
# Display unique values for each column with counts
for column in data_desciptives.columns:
    unique_values = data_desciptives[column].value_counts()
    print(f"\n{unique_values}\n")
# Out:
# model_info_model
# xgb    4800
# Name: count, dtype: int64
#
#
# model_info_n_train
# 200     2400
# 1000    2400
# Name: count, dtype: int64
#
#
# model_info_n_test
# 100000    4800
# Name: count, dtype: int64
#
#
# model_info_n_features
# 8    4800
# Name: count, dtype: int64
#
#
# model_info_noise
# 0    2400
# 3    2400
# Name: count, dtype: int64
#
#
# model_info_transformation
# identity    1600
# log         1600
# sqrt        1600
# Name: count, dtype: int64
#
#
# model_info_group_size
# 5     2400
# 10    2400
# Name: count, dtype: int64
#
#
# model_info_n_folds
# 5    4800
# Name: count, dtype: int64
#
#
# model_info_n_iter
# 200    4800
# Name: count, dtype: int64
#
#
# model_info_n_repetitions
# 50    2400
# 20     960
# 40     960
# 10     480
# Name: count, dtype: int64
#
#
# model_info_scoring
# neg_mean_squared_error    4800
# Name: count, dtype: int64
#
#
# model_info_n_jobs
# 1     4080
# -1     720
# Name: count, dtype: int64
#
#
# model_info_json_file
# /home/annegriddl/slds_stratification/Simulations/Final_Setup/results/xgb_rf7.json                                               1200
# c:\Users\anneg\Documents\Documents\StatistikMaster\slds_stratification\Simulations\Final_Setup/results/xgb/results_xgb3.json    1200
# /home/annegriddl/slds_stratification/Simulations/Final_Setup/results/results_xgb7.json                                           960
# c:\Users\anneg\Documents\Documents\StatistikMaster\slds_stratification\Simulations\Final_Setup/results/xgb/results_xgb4.json     480
# c:\Users\anneg\Documents\Documents\StatistikMaster\slds_stratification\Simulations\Final_Setup/results/xgb/results_xgb5.json     480
# c:\Users\anneg\Documents\Documents\StatistikMaster\slds_stratification\Simulations\Final_Setup/results/xgb/results_xgb1.json     240
# c:\Users\anneg\Documents\Documents\StatistikMaster\slds_stratification\Simulations\Final_Setup/results/xgb/results_xgb2.json     240
# Name: count, dtype: int64

# %%
# Filter columns that contain 'model_info'
model_vairables = ['model_info_model', 'model_info_n_train', 'model_info_n_test', 'model_info_n_features', 'model_info_noise', 'model_info_transformation', 'model_info_group_size', 'model_info_n_folds']

# Assuming data is your DataFrame
unique_row_counts = data[model_vairables].nunique(axis=0)

# Get the count of each unique combination of rows
unique_combinations_counts = data[model_vairables].groupby(model_vairables).size().reset_index(name='count')


print('Number of experiments per unique combinaiton:', unique_combinations_counts['count'].unique())
# Out:
# Number of experiments per unique combinaiton: [200]
