# %% [markdown]
# # Visualizations results

# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from utils_visualizations import flatten_data, filter_and_boxplot

# remove waringns
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_combined_boxplots(data_x, data_y, title):
    # check data format
    data_x = np.array(data_x).flatten()
    data_y = np.array(data_y).flatten()

    # Create a figure and a single subplot
    fig, ax = plt.subplots(figsize=(10, 5))

    # Plot box plots for data_x and data_y on the same subplot
    ax.boxplot([data_x, data_y], vert=False, labels=['stratified', 'unstratified'])
    ax.set_title(title)

    # Add labels and show the plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Load data for evaluation

# %%
# set file path
#file1 = "/Users/nadja/Documents/University/Master_Statistik/WS2023_24/SLDS/slds_stratification/Simulations/Final_Setup/results/results_rf1.json"
file = "/Users/nadja/Documents/University/Master_Statistik/WS2023_24/SLDS/slds_stratification/Simulations/Final_Setup/results/results_rf12.json"


# load data from json file
with open(file) as f:
    data= json.load(f)

# %%
# flatten dictionary and convert to dataframe
data_all_flatten, keys_dic = flatten_data(data)
data = pd.DataFrame(data_all_flatten)
print('Shape of data', data.shape)
print('Colum names of data', data.columns)
print('Number of Colums', data.columns.shape)
print('Keys of dictionary (', len(keys_dic), ')', keys_dic)


# check for duplicates ind data
print('Duplicates: ', data.astype(str).duplicated().sum())


data.head()
# Out:
# Shape of data (480, 75)
# Colum names of data Index(['model_info_model', 'model_info_n_train', 'model_info_n_test',
#        'model_info_n_features', 'model_info_noise',
#        'model_info_transformation', 'model_info_group_size',
#        'model_info_n_folds', 'model_info_n_iter', 'model_info_n_repetitions',
#        'model_info_scoring', 'model_info_n_jobs', 'model_info_json_file',
#        'repetition', 'random_state', 'hyperparameters_same',
#        'unstratified_results_train r2', 'unstratified_results_test r2',
#        'unstratified_results_train mse', 'unstratified_results_test mse',
#        'unstratified_results_train mae', 'unstratified_results_test mae',
#        'stratified_results_train r2', 'stratified_results_test r2',
#        'stratified_results_train mse', 'stratified_results_test mse',
#        'stratified_results_train mae', 'stratified_results_test mae',
#        'cv_unstratified_iterations_mean_fit_time',
#        'cv_unstratified_iterations_std_fit_time',
#        'cv_unstratified_iterations_mean_score_time',
#        'cv_unstratified_iterations_std_score_time',
#        'cv_unstratified_iterations_param_min_samples_split',
#        'cv_unstratified_iterations_param_min_samples_leaf',
#        'cv_unstratified_iterations_param_max_features',
#        'cv_unstratified_iterations_params',
#        'cv_unstratified_iterations_split0_test_score',
#        'cv_unstratified_iterations_split1_test_score',
#        'cv_unstratified_iterations_split2_test_score',
#        'cv_unstratified_iterations_split3_test_score',
#        'cv_unstratified_iterations_split4_test_score',
#        'cv_unstratified_iterations_mean_test_score',
#        'cv_unstratified_iterations_std_test_score',
#        'cv_unstratified_iterations_rank_test_score',
#        'cv_stratified_iterations_mean_fit_time',
#        'cv_stratified_iterations_std_fit_time',
#        'cv_stratified_iterations_mean_score_time',
#        'cv_stratified_iterations_std_score_time',
#        'cv_stratified_iterations_param_min_samples_split',
#        'cv_stratified_iterations_param_min_samples_leaf',
#        'cv_stratified_iterations_param_max_features',
#        'cv_stratified_iterations_params',
#        'cv_stratified_iterations_split0_test_score',
#        'cv_stratified_iterations_split1_test_score',
#        'cv_stratified_iterations_split2_test_score',
#        'cv_stratified_iterations_split3_test_score',
#        'cv_stratified_iterations_split4_test_score',
#        'cv_stratified_iterations_mean_test_score',
#        'cv_stratified_iterations_std_test_score',
#        'cv_stratified_iterations_rank_test_score',
#        'cv_iteration_refit_test_r2', 'cv_iteration_refit_test_mse',
#        'cv_iteration_refit_test_mae',
#        'cv_folds_descriptives_unstratified_ks_statistic',
#        'cv_folds_descriptives_unstratified_p_value',
#        'cv_folds_descriptives_unstratified_intersection_area',
#        'cv_folds_descriptives_stratified_ks_statistic',
#        'cv_folds_descriptives_stratified_p_value',
#        'cv_folds_descriptives_stratified_intersection_area',
#        'unstratified_best_params_min_samples_split',
#        'unstratified_best_params_min_samples_leaf',
#        'unstratified_best_params_max_features',
#        'stratified_best_params_min_samples_split',
#        'stratified_best_params_min_samples_leaf',
#        'stratified_best_params_max_features'],
#       dtype='object')
# Number of Colums (75,)
# Keys of dictionary ( 10 ) ['cv_stratified_iterations', 'cv_folds_descriptives_stratified', 'model_info', 'stratified_results', 'cv_folds_descriptives_unstratified', 'unstratified_results', 'cv_unstratified_iterations', 'cv_iteration_refit_test', 'unstratified_best_params', 'stratified_best_params']
# Duplicates:  0
#   model_info_model  model_info_n_train  model_info_n_test  \
# 0               rf                 200             100000
# 1               rf                 200             100000
# 2               rf                 200             100000
# 3               rf                 200             100000
# 4               rf                 200             100000
#
#    model_info_n_features  model_info_noise model_info_transformation  \
# 0                      8                 0                  identity
# 1                      8                 0                  identity
# 2                      8                 0                  identity
# 3                      8                 0                  identity
# 4                      8                 0                  identity
#
#    model_info_group_size  model_info_n_folds  model_info_n_iter  \
# 0                      5                   5                200
# 1                      5                   5                200
# 2                      5                   5                200
# 3                      5                   5                200
# 4                      5                   5                200
#
#    model_info_n_repetitions  ...  \
# 0                        20  ...
# 1                        20  ...
# 2                        20  ...
# 3                        20  ...
# 4                        20  ...
#
#   cv_folds_descriptives_unstratified_intersection_area  \
# 0                                           0.866526
# 1                                           0.851083
# 2                                           0.892708
# 3                                           0.858054
# 4                                           0.847100
#
#    cv_folds_descriptives_stratified_ks_statistic  \
# 0                                          0.025
# 1                                          0.025
# 2                                          0.025
# 3                                          0.025
# 4                                          0.025
#
#   cv_folds_descriptives_stratified_p_value  \
# 0                                      1.0
# 1                                      1.0
# 2                                      1.0
# 3                                      1.0
# 4                                      1.0
#
#    cv_folds_descriptives_stratified_intersection_area  \
# 0                                           0.962943
# 1                                           0.952666
# 2                                           0.955146
# 3                                           0.954002
# 4                                           0.940897
#
#    unstratified_best_params_min_samples_split  \
# 0                                           2
# 1                                           3
# 2                                           2
# 3                                           2
# 4                                           3
#
#    unstratified_best_params_min_samples_leaf  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
#
#    unstratified_best_params_max_features  \
# 0                                      5
# 1                                      5
# 2                                      7
# 3                                      4
# 4                                      6
#
#    stratified_best_params_min_samples_split  \
# 0                                         4
# 1                                         3
# 2                                         3
# 3                                         2
# 4                                         4
#
#    stratified_best_params_min_samples_leaf  \
# 0                                        1
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
#
#    stratified_best_params_max_features
# 0                                    7
# 1                                    5
# 2                                    6
# 3                                    6
# 4                                    5
#
# [5 rows x 75 columns]

# %% [markdown]
# ## Descriptives
# #### Single variables, no dictionnaries/lists
# * repetition', 'random_state', 'hyperparameters_same'
# * 'running_time_unstratified', 'running_time_stratified', 'running_time_repetition', 'cv_unstratified_iterations_mean_fit_time'

# %%
#  'hyperparameters_same'
data['hyperparameters_same'].value_counts()
# Out:
# hyperparameters_same
# False    325
# True     155
# Name: count, dtype: int64

# %%
# check 'random_state' unique
print(len(data['random_state']))
print(len(data['random_state'].unique()))
# Out:
# 480
# 480

# %%
# check 'repetition' complete
data['repetition'].value_counts().unique()
# Out:
# array([24])

# %% [markdown]
# ### Data dictionnaries in json file

# %%
# overview of keys
print('keys_dic:', len(keys_dic), keys_dic)
# Out:
# keys_dic: 10 ['cv_stratified_iterations', 'cv_folds_descriptives_stratified', 'model_info', 'stratified_results', 'cv_folds_descriptives_unstratified', 'unstratified_results', 'cv_unstratified_iterations', 'cv_iteration_refit_test', 'unstratified_best_params', 'stratified_best_params']

# %% [markdown]
# #### model_info

# %%
# Filter columns that contain 'model_info'
key = 'model_info'
colum = [col for col in data.columns if key in col] 
colum
# Out:
# ['model_info_model',
#  'model_info_n_train',
#  'model_info_n_test',
#  'model_info_n_features',
#  'model_info_noise',
#  'model_info_transformation',
#  'model_info_group_size',
#  'model_info_n_folds',
#  'model_info_n_iter',
#  'model_info_n_repetitions',
#  'model_info_scoring',
#  'model_info_n_jobs',
#  'model_info_json_file']

# %%
# give summary of every column
data_desciptives = data.loc[:, colum]
# in data_desciptives make all columns categorical
data_desciptives = data_desciptives.astype('category')
# show summary of every column
data_desciptives.describe(include='all')
# Out:
#        model_info_model  model_info_n_train  model_info_n_test  \
# count               480                 480                480
# unique                1                   2                  1
# top                  rf                 200             100000
# freq                480                 240                480
#
#         model_info_n_features  model_info_noise model_info_transformation  \
# count                     480               480                       480
# unique                      1                 2                         3
# top                         8                 0                  identity
# freq                      480               240                       160
#
#         model_info_group_size  model_info_n_folds  model_info_n_iter  \
# count                     480                 480                480
# unique                      2                   1                  1
# top                         5                   5                200
# freq                      240                 480                480
#
#         model_info_n_repetitions      model_info_scoring  model_info_n_jobs  \
# count                        480                     480                480
# unique                         1                       1                  1
# top                           20  neg_mean_squared_error                  1
# freq                         480                     480                480
#
#                                      model_info_json_file
# count                                                 480
# unique                                                  1
# top     /home/annegriddl/slds_stratification/Simulatio...
# freq                                                  480

# %%
# Display unique values for each column with counts
for column in data_desciptives.columns:
    unique_values = data_desciptives[column].value_counts()
    print(f"\n{unique_values}\n")
# Out:
# model_info_model
# rf    480
# Name: count, dtype: int64
#
#
# model_info_n_train
# 200     240
# 1000    240
# Name: count, dtype: int64
#
#
# model_info_n_test
# 100000    480
# Name: count, dtype: int64
#
#
# model_info_n_features
# 8    480
# Name: count, dtype: int64
#
#
# model_info_noise
# 0    240
# 3    240
# Name: count, dtype: int64
#
#
# model_info_transformation
# identity    160
# log         160
# sqrt        160
# Name: count, dtype: int64
#
#
# model_info_group_size
# 5     240
# 10    240
# Name: count, dtype: int64
#
#
# model_info_n_folds
# 5    480
# Name: count, dtype: int64
#
#
# model_info_n_iter
# 200    480
# Name: count, dtype: int64
#
#
# model_info_n_repetitions
# 20    480
# Name: count, dtype: int64
#
#
# model_info_scoring
# neg_mean_squared_error    480
# Name: count, dtype: int64
#
#
# model_info_n_jobs
# 1    480
# Name: count, dtype: int64
#
#
# model_info_json_file
# /home/annegriddl/slds_stratification/Simulations/Final_Setup/results/results_rf1.json    480
# Name: count, dtype: int64

# %% [markdown]
# #### cv_folds_descreptives_stratified

# %%
statistics = ['ks_statistic', 'p_value', 'intersection_area']

for s in statistics:
    s_stratified = '_stratified_' + s
    s_unstratified = '_unstratified_' + s
    s_stratified = [col for col in data.columns if s_stratified in col]
    s_unstratified = [col for col in data.columns if s_unstratified in col]
    #print(len(data[s_stratified]))

    plot_combined_boxplots(data_x= data[s_stratified], data_y = data[s_unstratified], title= s)

# %% [markdown]
# #### cv_unstratified_iterations

# %%
key = 'cv_stratified_iterations'
print(key)
colum1 = [col for col in data.columns if key in col]

key = 'cv_unstratified_iterations'
print(key)
colum2 = [col for col in data.columns if key in col]

colum = colum1 + colum2

print(len(colum))
# Out:
# cv_stratified_iterations
# cv_unstratified_iterations
# 32

# %%
data[colum]
# Out:
#                 cv_stratified_iterations_mean_fit_time  \
# 0    [0.6216261386871338, 0.7308226585388183, 0.610...
# 1    [0.5429324150085449, 0.4895612716674805, 0.600...
# 2    [0.7703309535980225, 0.6992202758789062, 0.600...
# 3    [0.717583417892456, 0.5925168037414551, 0.9652...
# 4    [0.6422772407531738, 0.5764066219329834, 0.600...
# ..                                                 ...
# 475  [1.8810730934143067, 2.356425476074219, 2.5682...
# 476  [1.7303634643554688, 1.7197449207305908, 3.467...
# 477  [1.2308634757995605, 1.9808125972747803, 1.031...
# 478  [1.2162482738494873, 1.0821444511413574, 1.657...
# 479  [1.0622328758239745, 3.15519061088562, 0.82069...
#
#                  cv_stratified_iterations_std_fit_time  \
# 0    [0.028424127619529258, 0.025091723303882343, 0...
# 1    [0.002583182615233865, 0.06486413228240484, 0....
# 2    [0.090410978042109, 0.025029009204874775, 0.01...
# 3    [0.09257330398575306, 0.024283961059676944, 0....
# 4    [0.00990533127585005, 0.006191850698154121, 0....
# ..                                                 ...
# 475  [0.12210042644859474, 0.14589923716268013, 0.3...
# 476  [0.09400299622551223, 0.13857329144221828, 0.2...
# 477  [0.2224568318291605, 0.19819045336269941, 0.05...
# 478  [0.1228253591460633, 0.2801754545972217, 0.294...
# 479  [0.030752488704198503, 0.030224893168644757, 0...
#
#               cv_stratified_iterations_mean_score_time  \
# 0    [0.01611752510070801, 0.01685299873352051, 0.0...
# 1    [0.019530487060546876, 0.016544437408447264, 0...
# 2    [0.020316219329833983, 0.024590063095092773, 0...
# 3    [0.01717529296875, 0.016771936416625978, 0.020...
# 4    [0.019012975692749023, 0.019412946701049805, 0...
# ..                                                 ...
# 475  [0.03139076232910156, 0.034897565841674805, 0....
# 476  [0.025084972381591797, 0.032877540588378905, 0...
# 477  [0.028457832336425782, 0.033291053771972653, 0...
# 478  [0.025979137420654295, 0.02932896614074707, 0....
# 479  [0.029935312271118165, 0.027742528915405275, 0...
#
#                cv_stratified_iterations_std_score_time  \
# 0    [0.0012790300646356822, 0.0008941505726133884,...
# 1    [0.0016829793008844675, 0.0037090836651996486,...
# 2    [0.0018598188715566407, 0.0018475607959627016,...
# 3    [0.0012313951715769765, 0.0005766986478569264,...
# 4    [0.0011520187130693888, 0.0014158964090862612,...
# ..                                                 ...
# 475  [0.012406035243805466, 0.005507233525886569, 0...
# 476  [0.004758531457083057, 0.0052253494872776625, ...
# 477  [0.006219589597078198, 0.009410062319391635, 0...
# 478  [0.0010071265935089587, 0.0054570944509419106,...
# 479  [0.0049798263653489825, 0.0039022464673881246,...
#
#       cv_stratified_iterations_param_min_samples_split  \
# 0    [10, 8, 4, 9, 9, 9, 2, 6, 2, 6, 6, 6, 3, 4, 2,...
# 1    [7, 8, 9, 9, 10, 4, 8, 10, 3, 7, 7, 7, 6, 4, 8...
# 2    [8, 10, 5, 2, 10, 9, 6, 3, 5, 6, 5, 8, 4, 4, 7...
# 3    [2, 5, 2, 2, 3, 3, 3, 7, 6, 2, 7, 4, 6, 8, 6, ...
# 4    [6, 2, 6, 9, 7, 8, 7, 5, 3, 4, 10, 9, 4, 9, 7,...
# ..                                                 ...
# 475  [9, 8, 2, 3, 9, 6, 9, 3, 5, 3, 5, 7, 9, 7, 2, ...
# 476  [7, 7, 2, 7, 7, 3, 4, 8, 3, 4, 5, 4, 9, 10, 3,...
# 477  [6, 10, 3, 2, 10, 6, 6, 2, 8, 9, 9, 8, 4, 10, ...
# 478  [5, 7, 5, 5, 10, 5, 7, 10, 10, 2, 9, 7, 2, 9, ...
# 479  [3, 5, 8, 8, 10, 10, 10, 3, 2, 6, 2, 8, 7, 10,...
#
#        cv_stratified_iterations_param_min_samples_leaf  \
# 0    [6, 2, 8, 6, 5, 10, 10, 5, 2, 10, 10, 8, 10, 1...
# 1    [7, 7, 4, 1, 1, 2, 3, 8, 6, 7, 10, 7, 8, 10, 5...
# 2    [1, 5, 5, 3, 2, 6, 10, 5, 8, 3, 4, 2, 9, 4, 2,...
# 3    [4, 3, 1, 3, 3, 1, 3, 6, 10, 5, 10, 4, 10, 6, ...
# 4    [9, 10, 3, 3, 2, 4, 1, 6, 8, 10, 9, 4, 9, 8, 2...
# ..                                                 ...
# 475  [7, 4, 9, 7, 9, 8, 4, 9, 8, 3, 9, 4, 3, 6, 7, ...
# 476  [8, 4, 2, 10, 2, 1, 5, 3, 10, 9, 2, 6, 10, 6, ...
# 477  [8, 7, 3, 7, 2, 5, 7, 4, 6, 7, 2, 6, 4, 10, 6,...
# 478  [3, 4, 9, 10, 7, 5, 10, 3, 8, 3, 1, 9, 9, 10, ...
# 479  [2, 3, 6, 1, 4, 8, 5, 1, 5, 9, 10, 7, 2, 4, 5,...
#
#            cv_stratified_iterations_param_max_features  \
# 0    [6, 8, 3, 2, 6, 4, 7, 1, 5, 1, 2, 6, 4, 6, 8, ...
# 1    [1, 1, 3, 8, 1, 2, 6, 2, 5, 6, 7, 5, 6, 5, 8, ...
# 2    [6, 6, 2, 2, 8, 8, 6, 1, 8, 4, 1, 8, 2, 7, 7, ...
# 3    [6, 3, 8, 7, 3, 4, 6, 3, 4, 7, 1, 5, 1, 5, 8, ...
# 4    [6, 3, 2, 5, 3, 1, 7, 3, 2, 1, 5, 8, 1, 8, 7, ...
# ..                                                 ...
# 475  [5, 6, 8, 5, 7, 8, 7, 7, 1, 7, 6, 8, 8, 7, 4, ...
# 476  [5, 4, 7, 1, 4, 3, 4, 5, 5, 7, 4, 8, 4, 5, 2, ...
# 477  [2, 5, 1, 2, 3, 1, 5, 7, 6, 4, 6, 4, 7, 4, 7, ...
# 478  [2, 1, 4, 2, 6, 7, 5, 5, 8, 4, 6, 1, 3, 2, 5, ...
# 479  [1, 8, 1, 7, 1, 3, 7, 5, 8, 8, 1, 4, 4, 5, 8, ...
#
#                        cv_stratified_iterations_params  \
# 0    [{'min_samples_split': 10, 'min_samples_leaf':...
# 1    [{'min_samples_split': 7, 'min_samples_leaf': ...
# 2    [{'min_samples_split': 8, 'min_samples_leaf': ...
# 3    [{'min_samples_split': 2, 'min_samples_leaf': ...
# 4    [{'min_samples_split': 6, 'min_samples_leaf': ...
# ..                                                 ...
# 475  [{'min_samples_split': 9, 'min_samples_leaf': ...
# 476  [{'min_samples_split': 7, 'min_samples_leaf': ...
# 477  [{'min_samples_split': 6, 'min_samples_leaf': ...
# 478  [{'min_samples_split': 5, 'min_samples_leaf': ...
# 479  [{'min_samples_split': 3, 'min_samples_leaf': ...
#
#             cv_stratified_iterations_split0_test_score  \
# 0    [-8.399234417897409, -7.321867828980352, -9.69...
# 1    [-11.088322094471849, -11.088322094471849, -6....
# 2    [-6.680285048929892, -7.688071750813167, -9.39...
# 3    [-8.860367380656836, -8.772099692806322, -9.03...
# 4    [-6.374664565864209, -7.4301509062982545, -5.9...
# ..                                                 ...
# 475  [-0.15905855266374747, -0.15399655292323897, -...
# 476  [-0.168858419748, -0.1647142365053469, -0.1665...
# 477  [-0.1759432869203546, -0.15300506266088906, -0...
# 478  [-0.1850893189293103, -0.22620131615604733, -0...
# 479  [-0.2003908898616966, -0.1662689390995945, -0....
#
#             cv_stratified_iterations_split1_test_score  ...  \
# 0    [-7.279063907679687, -6.795156273851328, -7.86...  ...
# 1    [-13.250828443264776, -13.250828443264776, -6....  ...
# 2    [-4.187636997548029, -4.999093246744404, -7.85...  ...
# 3    [-5.744269584515101, -6.028844325256914, -4.87...  ...
# 4    [-7.069613612297653, -8.39678265941736, -7.477...  ...
# ..                                                 ...  ...
# 475  [-0.16273069297618478, -0.163406198719524, -0....  ...
# 476  [-0.18638054349815258, -0.18268849731713865, -...  ...
# 477  [-0.16773751722722005, -0.1537267450412808, -0...  ...
# 478  [-0.2083349370926929, -0.24489112214909745, -0...  ...
# 479  [-0.19951833605483402, -0.15901426659017212, -...  ...
#
#          cv_unstratified_iterations_param_max_features  \
# 0    [6, 8, 3, 2, 6, 4, 7, 1, 5, 1, 2, 6, 4, 6, 8, ...
# 1    [1, 1, 3, 8, 1, 2, 6, 2, 5, 6, 7, 5, 6, 5, 8, ...
# 2    [6, 6, 2, 2, 8, 8, 6, 1, 8, 4, 1, 8, 2, 7, 7, ...
# 3    [6, 3, 8, 7, 3, 4, 6, 3, 4, 7, 1, 5, 1, 5, 8, ...
# 4    [6, 3, 2, 5, 3, 1, 7, 3, 2, 1, 5, 8, 1, 8, 7, ...
# ..                                                 ...
# 475  [5, 6, 8, 5, 7, 8, 7, 7, 1, 7, 6, 8, 8, 7, 4, ...
# 476  [5, 4, 7, 1, 4, 3, 4, 5, 5, 7, 4, 8, 4, 5, 2, ...
# 477  [2, 5, 1, 2, 3, 1, 5, 7, 6, 4, 6, 4, 7, 4, 7, ...
# 478  [2, 1, 4, 2, 6, 7, 5, 5, 8, 4, 6, 1, 3, 2, 5, ...
# 479  [1, 8, 1, 7, 1, 3, 7, 5, 8, 8, 1, 4, 4, 5, 8, ...
#
#                      cv_unstratified_iterations_params  \
# 0    [{'min_samples_split': 10, 'min_samples_leaf':...
# 1    [{'min_samples_split': 7, 'min_samples_leaf': ...
# 2    [{'min_samples_split': 8, 'min_samples_leaf': ...
# 3    [{'min_samples_split': 2, 'min_samples_leaf': ...
# 4    [{'min_samples_split': 6, 'min_samples_leaf': ...
# ..                                                 ...
# 475  [{'min_samples_split': 9, 'min_samples_leaf': ...
# 476  [{'min_samples_split': 7, 'min_samples_leaf': ...
# 477  [{'min_samples_split': 6, 'min_samples_leaf': ...
# 478  [{'min_samples_split': 5, 'min_samples_leaf': ...
# 479  [{'min_samples_split': 3, 'min_samples_leaf': ...
#
#           cv_unstratified_iterations_split0_test_score  \
# 0    [-7.504843477568036, -6.180812730678116, -9.68...
# 1    [-15.127509215456897, -15.127509215456897, -8....
# 2    [-5.542898916419066, -6.5448219165453, -7.7673...
# 3    [-5.96244302689342, -6.113392714435847, -5.402...
# 4    [-7.235544834548174, -7.420489737106216, -6.35...
# ..                                                 ...
# 475  [-0.11598377693935596, -0.11676133004533824, -...
# 476  [-0.18172578542620355, -0.18071523806154297, -...
# 477  [-0.18974664763904656, -0.18605804519974783, -...
# 478  [-0.22537781521586375, -0.27146453305315077, -...
# 479  [-0.18450985495839645, -0.13032766592332318, -...
#
#           cv_unstratified_iterations_split1_test_score  \
# 0    [-6.1379653448302545, -5.428976261710565, -7.1...
# 1    [-9.75092873040941, -9.75092873040941, -4.6874...
# 2    [-5.046086391601543, -5.609076993632117, -7.60...
# 3    [-6.690865479769371, -5.513052211612134, -6.45...
# 4    [-8.117075993616686, -8.78250238246225, -6.973...
# ..                                                 ...
# 475  [-0.1747060759520081, -0.16844721297088797, -0...
# 476  [-0.19368680307563857, -0.18754274144819377, -...
# 477  [-0.1469669009448897, -0.1344545412250164, -0....
# 478  [-0.17594976194498585, -0.20487338707858865, -...
# 479  [-0.23120782175350973, -0.21382602199314676, -...
#
#           cv_unstratified_iterations_split2_test_score  \
# 0    [-8.728539765580141, -8.048209837146045, -11.3...
# 1    [-21.722362421129365, -21.722362421129365, -12...
# 2    [-4.743109981570337, -5.514802184353156, -7.64...
# 3    [-7.759642587151154, -7.935373280892873, -6.99...
# 4    [-9.316379959370233, -12.453303896048206, -10....
# ..                                                 ...
# 475  [-0.13397201442970885, -0.1288142595045481, -0...
# 476  [-0.17222363705170213, -0.16431451885482673, -...
# 477  [-0.15807943292288196, -0.1418401851830958, -0...
# 478  [-0.18499948668489322, -0.21456645375258, -0.1...
# 479  [-0.17920743716912674, -0.16179685516871398, -...
#
#           cv_unstratified_iterations_split3_test_score  \
# 0    [-5.686813013509616, -5.636769967933281, -5.43...
# 1    [-11.087399532866078, -11.087399532866078, -5....
# 2    [-3.7708225037099345, -4.369415337273022, -5.6...
# 3    [-7.272873957756177, -7.482123930247004, -6.67...
# 4    [-4.541072695667963, -4.911208209229559, -3.93...
# ..                                                 ...
# 475  [-0.1921951839372185, -0.1891030578578178, -0....
# 476  [-0.11780263700817326, -0.1164214164638874, -0...
# 477  [-0.1988487935727863, -0.18160648739839455, -0...
# 478  [-0.16959922772087704, -0.19974614990010828, -...
# 479  [-0.1673339037835607, -0.14937212278598813, -0...
#
#           cv_unstratified_iterations_split4_test_score  \
# 0    [-6.289878892666323, -4.923230436382448, -7.37...
# 1    [-7.780166580506619, -7.780166580506619, -5.19...
# 2    [-6.243392521285025, -6.763505704088466, -9.98...
# 3    [-5.838302025174815, -6.269903671929498, -5.39...
# 4    [-9.383804547125887, -9.378665600225753, -7.25...
# ..                                                 ...
# 475  [-0.18186171875622054, -0.18404933731012085, -...
# 476  [-0.18271761148236243, -0.1825434119785861, -0...
# 477  [-0.1976709208578321, -0.17161768896689414, -0...
# 478  [-0.18091256932695615, -0.21965186712986154, -...
# 479  [-0.23899293125779142, -0.1730733701264292, -0...
#
#             cv_unstratified_iterations_mean_test_score  \
# 0    [-6.869608098830875, -6.043599846770091, -8.18...
# 1    [-13.093673296073675, -13.093673296073675, -7....
# 2    [-5.069262062917181, -5.760324427178412, -7.72...
# 3    [-6.704825415348987, -6.662769161823471, -6.18...
# 4    [-7.718775606065788, -8.589233965014396, -7.02...
# ..                                                 ...
# 475  [-0.1597437540029024, -0.1574350395377426, -0....
# 476  [-0.169631294808816, -0.1663074653614074, -0.1...
# 477  [-0.1782625391874873, -0.16311538959462973, -0...
# 478  [-0.1873677721787152, -0.22206047818285785, -0...
# 479  [-0.200250389784477, -0.16567920719952026, -0....
#
#              cv_unstratified_iterations_std_test_score  \
# 0    [1.1072074976141073, 1.080350767703119, 2.0684...
# 1    [4.940105137027289, 4.940105137027289, 2.95471...
# 2    [0.8241082189960693, 0.8531815796679582, 1.385...
# 3    [0.7399334684509108, 0.902094265596221, 0.6659...
# 4    [1.7784606831909746, 2.46922773150879, 2.14586...
# ..                                                 ...
# 475  [0.029479785959026773, 0.02934604534699733, 0....
# 476  [0.026792259602616428, 0.026133184029507532, 0...
# 477  [0.021536660126886348, 0.021045920226198618, 0...
# 478  [0.01968823974646393, 0.025675076608765546, 0....
# 479  [0.029097809044531957, 0.027941061361821173, 0...
#
#             cv_unstratified_iterations_rank_test_score
# 0    [78, 19, 147, 160, 55, 153, 139, 185, 8, 200, ...
# 1    [184, 184, 49, 37, 170, 52, 30, 162, 66, 100, ...
# 2    [20, 65, 157, 124, 48, 73, 132, 189, 109, 44, ...
# 3    [47, 39, 8, 22, 39, 3, 24, 102, 152, 75, 198, ...
# 4    [122, 159, 86, 40, 47, 180, 16, 101, 163, 199,...
# ..                                                 ...
# 475  [80, 34, 156, 80, 143, 138, 59, 143, 193, 54, ...
# 476  [110, 16, 57, 199, 2, 56, 48, 14, 137, 124, 10...
# 477  [160, 88, 171, 158, 83, 180, 88, 16, 56, 90, 5...
# 478  [135, 187, 114, 181, 90, 79, 130, 32, 147, 3, ...
# 479  [172, 42, 188, 69, 184, 131, 77, 29, 88, 142, ...
#
# [480 rows x 32 columns]

# %%
colum
# Out:
# ['cv_stratified_iterations_mean_fit_time',
#  'cv_stratified_iterations_std_fit_time',
#  'cv_stratified_iterations_mean_score_time',
#  'cv_stratified_iterations_std_score_time',
#  'cv_stratified_iterations_param_min_samples_split',
#  'cv_stratified_iterations_param_min_samples_leaf',
#  'cv_stratified_iterations_param_max_features',
#  'cv_stratified_iterations_params',
#  'cv_stratified_iterations_split0_test_score',
#  'cv_stratified_iterations_split1_test_score',
#  'cv_stratified_iterations_split2_test_score',
#  'cv_stratified_iterations_split3_test_score',
#  'cv_stratified_iterations_split4_test_score',
#  'cv_stratified_iterations_mean_test_score',
#  'cv_stratified_iterations_std_test_score',
#  'cv_stratified_iterations_rank_test_score',
#  'cv_unstratified_iterations_mean_fit_time',
#  'cv_unstratified_iterations_std_fit_time',
#  'cv_unstratified_iterations_mean_score_time',
#  'cv_unstratified_iterations_std_score_time',
#  'cv_unstratified_iterations_param_min_samples_split',
#  'cv_unstratified_iterations_param_min_samples_leaf',
#  'cv_unstratified_iterations_param_max_features',
#  'cv_unstratified_iterations_params',
#  'cv_unstratified_iterations_split0_test_score',
#  'cv_unstratified_iterations_split1_test_score',
#  'cv_unstratified_iterations_split2_test_score',
#  'cv_unstratified_iterations_split3_test_score',
#  'cv_unstratified_iterations_split4_test_score',
#  'cv_unstratified_iterations_mean_test_score',
#  'cv_unstratified_iterations_std_test_score',
#  'cv_unstratified_iterations_rank_test_score']

# %% [markdown]
# Fit time stratified vs. unstratiffied:

# %%
mean_fit_time_stratified = [np.mean(x) for x in data['cv_stratified_iterations_mean_fit_time']]
mean_fit_time_unstratified = [np.mean(x) for x in data['cv_unstratified_iterations_mean_fit_time']]

plot_combined_boxplots( mean_fit_time_stratified, mean_fit_time_unstratified, 'Running Times')

# %% [markdown]
# Unstratified: Negative MSE

# %%
print(f"Unstratified: Negative MSE {np.mean(data['cv_unstratified_iterations_mean_test_score'].explode().tolist())} with sd of  {np.sqrt(np.var(data['cv_unstratified_iterations_std_test_score'].explode().tolist()))}")
print(f"Stratified: Negative MSE {np.mean(data['cv_stratified_iterations_mean_test_score'].explode().tolist())} with sd of {np.sqrt(np.var(data['cv_stratified_iterations_std_test_score'].explode().tolist()))}")
# Out:
# Unstratified: Negative MSE -3.4939069376480982 with sd of  1.1021792451416155
# Stratified: Negative MSE -3.462453565990341 with sd of 0.655832311444123

# %%
data['cv_stratified_iterations_rank_test_score'].shape
# Out:
# (480,)

# %%
from scipy.stats import spearmanr

correlation_coefficient_list = []
p_value_list = []

# Calculate Spearman's correlation coefficient and p-value for each iteration
for i in range(len(data['cv_stratified_iterations_mean_test_score'])):
    correlation_coefficient, p_value = spearmanr(data['cv_stratified_iterations_rank_test_score'][0], data['cv_unstratified_iterations_rank_test_score'][0]) #@nadja: cechk, test rank
    correlation_coefficient_list.append(correlation_coefficient)
    p_value_list.append(p_value)

# Print the mean and variance of the correlation coefficient
print("Mean of correlation coefficient:", np.mean(correlation_coefficient_list))
print("Variance of correlation coefficient:", np.var(correlation_coefficient_list))

# Print the mean and variance of the p-value
print("Mean of p-value:", np.mean(p_value_list))
print("Variance of p-value:", np.var(p_value_list))
# Out:
# Mean of correlation coefficient: 0.9986856704318611
# Variance of correlation coefficient: 4.930380657631324e-32
# Mean of p-value: 1.9013125067583867e-257
# Variance of p-value: 0.0

# %% [markdown]
# #### Gerneralisierungsfehler

# %%
gen_error_stratified_list = []
gen_error_unstratified_list = []

for i in range(len(data)):
    # generalisation error: stratified
    gen_error_stratified = np.array(data['cv_iteration_refit_test_mse'][i]) + np.array(data['cv_stratified_iterations_mean_test_score'][i])
    gen_error_stratified_list.append(gen_error_stratified) #@Nadja:append
    # generalisation error: unstratified
    gen_error_unstratified = np.array(data['cv_iteration_refit_test_mse'][i]) + np.array(data['cv_unstratified_iterations_mean_test_score'][i]) #true estimation - validation
    gen_error_unstratified_list.append(gen_error_unstratified)


# plot gen_error_stratified and gen_error_unstratified in two boxplots next to each other

plot_combined_boxplots(gen_error_stratified_list, gen_error_unstratified_list, title = 'Generalisation Error')

print(np.mean(gen_error_stratified_list))
print(np.mean(gen_error_unstratified_list))
# Out:
# -0.11985669115034062
# -0.15131006280809908

# %% [markdown]
# Best Hyperparmetrs: TBD

# %% [markdown]
# #### cv_iteration_refit_test'

# %%
key = 'cv_iteration_refit_test'
print(key)
colum= [col for col in data.columns if key in col]
colum
# Out:
# cv_iteration_refit_test
# ['cv_iteration_refit_test_r2',
#  'cv_iteration_refit_test_mse',
#  'cv_iteration_refit_test_mae']

# %% [markdown]
# #### Boxplots Evaluation metrics:  'unstratified_results' and 'stratified_results'

# %%
parameter_grid = {
    "model_info_model": 'rf',
    "model_info_transformation": None,
    "model_info_n_train": 200,
    "model_info_group_size": 10,
    "model_info_n_folds": 5,
    "model_info_n_iter": 200,
    "model_info_noise": 0,
    "model_info_scoring": 'neg_mean_squared_error'
}
value1 = 'identity'
value2 = 'log'

df1, df2 = filter_and_boxplot(data, parameter_grid, value1, value2)
print(df1)
print(df2)
# Out:
# (20, 75)
# (20, 75)
#                 mean_diff   sd_diff
# diff_train_r2   -0.000639  0.004816
# diff_test_r2     0.000526  0.003224
# diff_train_mse   0.010615  0.105807
# diff_test_mse   -0.012555  0.076989
# diff_train_mae   0.003946  0.040942
# diff_test_mae   -0.002414  0.013079
#                 mean_diff   sd_diff
# diff_train_r2    0.000676  0.013713
# diff_test_r2    -0.000859  0.004107
# diff_train_mse  -0.000061  0.002232
# diff_test_mse    0.000137  0.000657
# diff_train_mae  -0.000396  0.007099
# diff_test_mae    0.000285  0.001227

# %%
parameter_grid = {
    "model_info_model": 'rf',
    "model_info_transformation": 'identity',
    "model_info_n_train": 200,
    "model_info_group_size": 10,
    "model_info_n_folds": 5,
    "model_info_n_iter": 200,
    "model_info_noise": None,
    "model_info_scoring": 'neg_mean_squared_error'
}
value1 = 0
value2 = 3

df1, df2 = filter_and_boxplot(data, parameter_grid, value1, value2)
print(df1)
print(df2)
# Out:
# (20, 75)
# (20, 75)
#                 mean_diff   sd_diff
# diff_train_r2   -0.000639  0.004816
# diff_test_r2     0.000526  0.003224
# diff_train_mse   0.010615  0.105807
# diff_test_mse   -0.012555  0.076989
# diff_train_mae   0.003946  0.040942
# diff_test_mae   -0.002414  0.013079
#                 mean_diff   sd_diff
# diff_train_r2   -0.015691  0.026884
# diff_test_r2     0.001965  0.007230
# diff_train_mse   0.500612  0.867694
# diff_test_mse   -0.064523  0.237436
# diff_train_mae   0.105211  0.180768
# diff_test_mae   -0.006300  0.024557

# %% [markdown]
# Note @Nadja: Differenzen definieren !!!!
